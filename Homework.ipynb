# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("IMDB Dataset.csv")
df.head(3)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A      142
# 1             The Godfather           1972           A      175
# 2           The Dark Knight           2008          UA      152
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview              Director  \
# 0  Two imprisoned men bond over a number of years...        Frank Darabont
# 1  An organized crime dynasty's aging patriarch t...  Francis Ford Coppola
# 2  When the menace known as the Joker wreaks havo...     Christopher Nolan
#
# ...

# %%
df.tail(3)
# Out:
#                                            Poster_Link    Series_Title  \
# 197  https://m.media-amazon.com/images/M/MV5BZGRkOG...  Koe no katachi
# 198  https://m.media-amazon.com/images/M/MV5BMDk0Yz...    Contratiempo
# 199  https://m.media-amazon.com/images/M/MV5BNDJhYT...       Ah-ga-ssi
#
#      Released_Year Certificate  Runtime                     Genre  \
# 197           2016          16      130  Animation, Drama, Family
# 198           2016       TV-MA      106     Crime, Drama, Mystery
# 199           2016           A      145  Drama, Romance, Thriller
#
#      IMDB_Rating                                           Overview  \
# 197          8.1  A young man is ostracized by his classmates af...
# 198          8.1  A successful entrepreneur accused of murder an...
# 199          8.1  A woman is hired as a handmaiden to a Japanese...
#
#            Director        Star1         Star2          Star3           Star4  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    200 non-null    object
#  1   Series_Title   200 non-null    object
#  2   Released_Year  200 non-null    int64
#  3   Certificate    200 non-null    object
#  4   Runtime        200 non-null    int64
#  5   Genre          200 non-null    object
#  6   IMDB_Rating    200 non-null    float64
#  7   Overview       200 non-null    object
#  8   Director       200 non-null    object
#  9   Star1          200 non-null    object
#  10  Star2          200 non-null    object
#  11  Star3          200 non-null    object
#  12  Star4          200 non-null    object
#  13  No_of_Votes    200 non-null    int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 22.0+ KB

# %%
df.isnull().sum()
# Out:
# Poster_Link      0
# Series_Title     0
# Released_Year    0
# Certificate      0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Overview         0
# Director         0
# Star1            0
# Star2            0
# Star3            0
# Star4            0
# No_of_Votes      0
# dtype: int64

# %%
subset_df = df.iloc[40:75]
print(subset_df)
# Out:
#                                           Poster_Link  \
# 40  https://m.media-amazon.com/images/M/MV5BZjA0MT...
# 41  https://m.media-amazon.com/images/M/MV5BYTViNj...
# 42  https://m.media-amazon.com/images/M/MV5BODllNW...
# 43  https://m.media-amazon.com/images/M/MV5BYTYxNG...
# 44  https://m.media-amazon.com/images/M/MV5BMGU2Nz...
# 45  https://m.media-amazon.com/images/M/MV5BM2FhYj...
# 46  https://m.media-amazon.com/images/M/MV5BZmY2Nj...
# 47  https://m.media-amazon.com/images/M/MV5BZmU0M2...
# 48  https://m.media-amazon.com/images/M/MV5BZGI5Mj...
# 49  https://m.media-amazon.com/images/M/MV5BNTQwND...
# 50  https://m.media-amazon.com/images/M/MV5BY2IzZG...
# 51  https://m.media-amazon.com/images/M/MV5BYjJiZj...
# 52  https://m.media-amazon.com/images/M/MV5BY2I4Mm...
# 53  https://m.media-amazon.com/images/M/MV5BMmExNz...
# 54  https://m.media-amazon.com/images/M/MV5BNWJhMD...
# 55  https://m.media-amazon.com/images/M/MV5BY2FiMT...
# ...

# %%
highest_votes_movie = df.loc[df['No_of_Votes'].idxmax()]
print(highest_votes_movie)
# Out:
# Poster_Link      https://m.media-amazon.com/images/M/MV5BMDFkYT...
# Series_Title                              The Shawshank Redemption
# Released_Year                                                 1994
# Certificate                                                      A
# Runtime                                                        142
# Genre                                                        Drama
# IMDB_Rating                                                    9.3
# Overview         Two imprisoned men bond over a number of years...
# Director                                            Frank Darabont
# Star1                                                  Tim Robbins
# Star2                                               Morgan Freeman
# Star3                                                   Bob Gunton
# Star4                                               William Sadler
# No_of_Votes                                                2343110
# Name: 0, dtype: object

# %%
df[["IMDB_Rating", "Runtime"]].plot(kind = 'box', subplots=True, layout=(3,2), sharex=False, sharey=False, figsize=(12,8))
plt.show()

# %%
plt.scatter(df['Runtime'], df['IMDB_Rating']); plt.title("Relationship between IMDB Rating and Runtime")
# Out:
# Text(0.5, 1.0, 'Relationship between IMDB Rating and Runtime')

# %%
df[["IMDB_Rating", "Runtime"]].hist(figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'IMDB_Rating'}>,
#         <Axes: title={'center': 'Runtime'}>]], dtype=object)

# %%
sns.countplot('Rating')
# Out:
# <Axes: xlabel='count'>
